# %%
from Metrics import *

# %% [markdown]
# # Changing the num of users

# %% [markdown]
# ## Numerical experiments for loss systems

# %% [markdown]
# ## arrival rate - $\lambda=1$ (relative to service rate)

# %% [markdown]
# ### given availability - $\alpha = 0.1$

# %%
params={}
params['arrival_rate'] = 1
params['service_rate'] = 1
params['retrial_rate'] = 1
params['given_alpha'] = 0.1

all_n = np.arange(2, 50, 1)
results_min_servers, results_min_servers_lb, results_min_servers_ub, threshold = ComputeAllMinServers(params, all_n)
PlotAllPerformances(params, all_n, results_min_servers, results_min_servers_lb, results_min_servers_ub, threshold, 5, 1)
# Out:
# 48it [00:00, 18882.63it/s]

# %% [markdown]
# ### given availability - $\alpha = 0.5$

# %%
params['given_alpha'] = 0.5

all_n = np.arange(2, 100, 5)
results_min_servers, results_min_servers_lb, results_min_servers_ub, threshold = ComputeAllMinServers(params, all_n)
PlotAllPerformances(params, all_n, results_min_servers, results_min_servers_lb, results_min_servers_ub, threshold, 10, 8)
# Out:
# 20it [00:00, 25259.28it/s]

# %% [markdown]
# ### given availability - $\alpha = 0.9$

# %%
params['given_alpha'] = 0.9

all_n = np.arange(2500, 3000, 50)
results_min_servers, results_min_servers_lb, results_min_servers_ub, threshold = ComputeAllMinServers(params, all_n)
PlotAllPerformances(params, all_n, results_min_servers, results_min_servers_lb, results_min_servers_ub, threshold, 500, 300)
# Out:
# 10it [00:00, 255.87it/s]

# %% [markdown]
# ## arrival rate - $\lambda=3$

# %% [markdown]
# ### given availability - $\alpha = 0.1$

# %%
params={}
params['arrival_rate'] = 3
params['service_rate'] = 1
params['retrial_rate'] = 3
params['given_alpha'] = 0.1

all_n = np.arange(2, 50, 1)
results_min_servers, results_min_servers_lb, results_min_servers_ub, threshold = ComputeAllMinServers(params, all_n)
PlotAllPerformances(params, all_n, results_min_servers, results_min_servers_lb, results_min_servers_ub, threshold, 5, 1)
# Out:
# 48it [00:00, 22651.51it/s]

# %% [markdown]
# ### given availability - $\alpha = 0.5$

# %%
params={}
params['arrival_rate'] = 1
params['service_rate'] = 20
params['retrial_rate'] = 1

params['given_alpha'] = 0.9

all_n = np.arange(2, 20, 1)
results_min_servers, results_min_servers_lb, results_min_servers_ub, threshold = ComputeAllMinServers(params, all_n)
PlotAllPerformances(params, all_n, results_min_servers, results_min_servers_lb, results_min_servers_ub, threshold, 5, 2)
# Out:
# 18it [00:00, 32099.27it/s]

# %% [markdown]
# ### given availability - $\alpha = 0.9$

# %%
params['given_alpha'] = 0.9

all_n = np.arange(2, 4000, 50)
results_min_servers, results_min_servers_lb, results_min_servers_ub, threshold = ComputeAllMinServers(params, all_n)
PlotAllPerformances(params, all_n, results_min_servers, results_min_servers_lb, results_min_servers_ub, threshold, 500, 300)
# Out:
# 80it [00:00, 287.41it/s]

# %% [markdown]
# ## Simulation results for retrial systems

# %% [markdown]
# ### given availability - $\alpha = 0.1$

# %%
params={}
params['arrival_rate'] = 1
params['service_rate'] = 1
params['retrial_rate'] = 2

# %%
params['given_alpha'] = 0.1

all_n = np.arange(2, 30, 1)
results_min_servers, results_min_servers_lb, results_min_servers_ub, threshold = ComputeAllMinServers(params, all_n)
PlotAllPerformances(params, all_n, results_min_servers, results_min_servers_lb, results_min_servers_ub, threshold, 5, 1)
# Out:
# 28it [02:01,  4.35s/it]

# %% [markdown]
# ### given availability - $\alpha = 0.5$

# %%
params['given_alpha'] = 0.5

all_n = np.arange(2, 200, 10)
results_min_servers, results_min_servers_lb, results_min_servers_ub, threshold = ComputeAllMinServers(params, all_n)
PlotAllPerformances(params, all_n, results_min_servers, results_min_servers_lb, results_min_servers_ub, threshold, 20, 8)
# Out:
# 20it [33:30, 100.53s/it]

# %% [markdown]
# ### given availability - $\alpha = 0.9$

# %%
params['given_alpha'] = 0.9

all_n = np.arange(2, 12000, 1000)
results_min_servers, results_min_servers_lb, results_min_servers_ub, threshold = ComputeAllMinServers(params, all_n)
PlotAllPerformances(params, all_n, results_min_servers, results_min_servers_lb, results_min_servers_ub, threshold, 800, 300)
# Out:
# 2it [6:03:37, 12833.52s/it]

# %% [markdown]
# # Changing arrival rate $\lambda$

# %% [markdown]
# ## different $\alpha$

# %%
params={}
params['arrival_rate'] = 1
params['service_rate'] = 1
params['retrial_rate'] = 1
params['given_alpha'] = 0.1
params['num_of_users'] = 20

# %%
params['given_alpha'] = 0.1
all_lambdas = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_lambda(params, all_lambdas)
plot_all_perf_changing_var(params, all_lambdas, min_servers, min_servers_lb, min_servers_ub, 1, 1, r"$\lambda$", r"$m^*$")
# Out:
# 11it [01:21,  7.89s/it]

# %%
params['given_alpha'] = 0.5
all_lambdas = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_lambda(params, all_lambdas)
plot_all_perf_changing_var(params, all_lambdas, min_servers, min_servers_lb, min_servers_ub, 1, 1, r"$\lambda$", r"$m^*$")
# Out:
# 30it [04:21,  8.73s/it]

# %%
params['given_alpha'] = 0.9
all_lambdas = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_lambda(params, all_lambdas)
plot_all_perf_changing_var(params, all_lambdas, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\lambda$", r"$m^*$")
# Out:
# 30it [05:48, 11.61s/it]

# %% [markdown]
# ## different numbr of users

# %%
params={}
params['arrival_rate'] = 1
params['service_rate'] = 1
params['retrial_rate'] = 1
params['given_alpha'] = 0.9

# %%
params['num_of_users'] = 10
all_lambdas = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_lambda(params, all_lambdas)
plot_all_perf_changing_var(params, all_lambdas, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\lambda$", r"$m^*$")
# Out:
# 30it [01:41,  3.38s/it]

# %%
params['num_of_users'] = 20
all_lambdas = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_lambda(params, all_lambdas)
plot_all_perf_changing_var(params, all_lambdas, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\lambda$", r"$m^*$")
# Out:
# 30it [05:51, 11.71s/it]

# %%
params['num_of_users'] = 50
all_lambdas = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_lambda(params, all_lambdas)
plot_all_perf_changing_var(params, all_lambdas, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\lambda$", r"$m^*$")
# Out:
# 30it [28:23, 56.79s/it]

# %% [markdown]
# ## different service level

# %%
params={}
params['arrival_rate'] = 1
params['service_rate'] = 1
params['retrial_rate'] = 1
params['given_alpha'] = 0.9
params['num_of_users'] = 20
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
params['service_rate'] = 0.5
all_lambdas = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_lambda(params, all_lambdas)
plot_all_perf_changing_var(params, all_lambdas, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\lambda$", r"$m^*$")
# Out:
# 30it [03:23,  6.80s/it]

# %%
params['service_rate'] = 5
all_lambdas = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_lambda(params, all_lambdas)
plot_all_perf_changing_var(params, all_lambdas, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\lambda$", r"$m^*$")
# Out:
# 30it [16:47, 33.57s/it]

# %%
params['service_rate'] = 10
all_lambdas = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_lambda(params, all_lambdas)
plot_all_perf_changing_var(params, all_lambdas, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\lambda$", r"$m^*$")
# Out:
# 30it [17:42, 35.41s/it]

# %% [markdown]
# ## different retrial rate

# %%
params={}
params['arrival_rate'] = 1
params['service_rate'] = 1
params['retrial_rate'] = 1
params['given_alpha'] = 0.9
params['num_of_users'] = 20

# %%
params['retrial_rate'] = 0.5
all_lambdas = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_lambda(params, all_lambdas)
plot_all_perf_changing_var(params, all_lambdas, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\lambda$", r"$m^*$")
# Out:
# 30it [06:09, 12.30s/it]

# %%
params['retrial_rate'] = 5
all_lambdas = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_lambda(params, all_lambdas)
plot_all_perf_changing_var(params, all_lambdas, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\lambda$", r"$m^*$")
# Out:
# 30it [07:35, 15.19s/it]

# %%
params['retrial_rate'] = 10
all_lambdas = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_lambda(params, all_lambdas)
plot_all_perf_changing_var(params, all_lambdas, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\lambda$", r"$m^*$")
# Out:
# 30it [09:04, 18.14s/it]

# %% [markdown]
# # Changing service rate $\mu$

# %% [markdown]
# ## different arrival rates

# %%
params={}
params['arrival_rate'] = 1
params['service_rate'] = 1
params['retrial_rate'] = 1
params['given_alpha'] = 0.9
params['num_of_users'] = 20

# %%
params['arrival_rate'] = 0.5
all_mus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_mu(params, all_mus)
plot_all_perf_changing_var(params, all_mus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\mu$", r"$m^*$", "mu")
# Out:
# 30it [03:15,  6.50s/it]

# %%
params['arrival_rate'] = 5
all_mus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_mu(params, all_mus)
plot_all_perf_changing_var(params, all_mus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\mu$", r"$m^*$", "mu")
# Out:
# 30it [14:19, 28.65s/it]

# %%
params['arrival_rate'] = 10
all_mus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_mu(params, all_mus)
plot_all_perf_changing_var(params, all_mus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\mu$", r"$m^*$", "mu")
# Out:
# 30it [18:38, 37.28s/it]

# %% [markdown]
# ## different $\alpha$

# %%
params={}
params['arrival_rate'] = 1
params['service_rate'] = 1
params['retrial_rate'] = 1
params['given_alpha'] = 0.9
params['num_of_users'] = 20

# %%
params['given_alpha'] = 0.1
all_mus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_mu(params, all_mus)
plot_all_perf_changing_var(params, all_mus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\mu$", r"$m^*$", "mu")
# Out:
# 30it [00:00, 88737.04it/s]

# %%
params['given_alpha'] = 0.5
all_mus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_mu(params, all_mus)
plot_all_perf_changing_var(params, all_mus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\mu$", r"$m^*$", "mu")
# Out:
# 30it [00:00, 80197.02it/s]

# %%
params['given_alpha'] = 0.9
all_mus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_mu(params, all_mus)
plot_all_perf_changing_var(params, all_mus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\mu$", r"$m^*$", "mu")
# Out:
# 30it [00:00, 62851.71it/s]

# %% [markdown]
# ## different num of users

# %%
params={}
params['arrival_rate'] = 1
params['service_rate'] = 1
params['retrial_rate'] = 1
params['given_alpha'] = 0.9
params['num_of_users'] = 20

# %%
params['num_of_users'] = 5
all_mus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_mu(params, all_mus)
plot_all_perf_changing_var(params, all_mus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\mu$", r"$m^*$", "mu")
# Out:
# 30it [00:00, 148034.26it/s]

# %%
params['num_of_users'] = 10
all_mus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_mu(params, all_mus)
plot_all_perf_changing_var(params, all_mus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\mu$", r"$m^*$", "mu")
# Out:
# 30it [00:00, 59019.29it/s]

# %%
params['num_of_users'] = 50
all_mus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_mu(params, all_mus)
plot_all_perf_changing_var(params, all_mus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\mu$", r"$m^*$", "mu")
# Out:
# 30it [00:00, 35001.15it/s]

# %% [markdown]
# ## different retial rates

# %%
params={}
params['arrival_rate'] = 1
params['service_rate'] = 1
params['retrial_rate'] = 1
params['given_alpha'] = 0.9
params['num_of_users'] = 20

# %%
params['retrial_rate'] = 0.5
all_mus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_mu(params, all_mus)
plot_all_perf_changing_var(params, all_mus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\mu$", r"$m^*$", "mu")
# Out:
# 30it [05:24, 10.82s/it]

# %%
params['retrial_rate'] = 5
all_mus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_mu(params, all_mus)
plot_all_perf_changing_var(params, all_mus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\mu$", r"$m^*$", "mu")
# Out:
# 30it [06:37, 13.24s/it]

# %%
params['retrial_rate'] = 10
all_mus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_mu(params, all_mus)
plot_all_perf_changing_var(params, all_mus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\mu$", r"$m^*$", "mu")
# Out:
# 30it [07:03, 14.13s/it]

# %% [markdown]
# # Changing retrial rate $\nu$

# %% [markdown]
# ## different arrival rates

# %%
params={}
params['arrival_rate'] = 1
params['service_rate'] = 1
params['retrial_rate'] = 1
params['given_alpha'] = 0.9
params['num_of_users'] = 20

# %%
params['arrival_rate'] = 0.5
all_nus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_nu(params, all_nus)
plot_all_perf_changing_var(params, all_nus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\nu$", r"$m^*$", "nu")
# Out:
# 30it [03:09,  6.33s/it]

# %%
params['arrival_rate'] = 5
all_nus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_nu(params, all_nus)
plot_all_perf_changing_var(params, all_nus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\nu$", r"$m^*$", "nu")
# Out:
# 30it [08:01, 16.05s/it]

# %%
params['arrival_rate'] = 10
all_nus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_nu(params, all_nus)
plot_all_perf_changing_var(params, all_nus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\nu$", r"$m^*$", "nu")
# Out:
# 30it [08:27, 16.90s/it]

# %% [markdown]
# ## different $\alpha$

# %%
params={}
params['arrival_rate'] = 1
params['service_rate'] = 1
params['retrial_rate'] = 1
params['given_alpha'] = 0.1
params['num_of_users'] = 20

# %%
params['given_alpha'] = 0.1
all_nus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_nu(params, all_nus)
plot_all_perf_changing_var(params, all_nus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\nu$", r"$m^*$", "nu")
# Out:
# 30it [09:02, 18.09s/it]

# %%
params['given_alpha'] = 0.5
all_nus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_nu(params, all_nus)
plot_all_perf_changing_var(params, all_nus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\nu$", r"$m^*$", "nu")
# Out:
# 30it [05:17, 10.58s/it]

# %%
params['given_alpha'] = 0.9
all_nus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_nu(params, all_nus)
plot_all_perf_changing_var(params, all_nus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\nu$", r"$m^*$", "nu")
# Out:
# 30it [04:20,  8.68s/it]

# %% [markdown]
# ## different num of users

# %%
params={}
params['arrival_rate'] = 1
params['service_rate'] = 1
params['retrial_rate'] = 1
params['given_alpha'] = 0.9
params['num_of_users'] = 20

# %%
params['num_of_users'] = 5
all_nus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_nu(params, all_nus)
plot_all_perf_changing_var(params, all_nus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\nu$", r"$m^*$", "nu")
# Out:
# 30it [00:25,  1.18it/s]

# %%
params['num_of_users'] = 10
all_nus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_nu(params, all_nus)
plot_all_perf_changing_var(params, all_nus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\nu$", r"$m^*$", "nu")
# Out:
# 30it [01:29,  3.00s/it]

# %%
params['num_of_users'] = 50
all_nus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_nu(params, all_nus)
plot_all_perf_changing_var(params, all_nus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\nu$", r"$m^*$", "nu")
# Out:
# 30it [21:58, 43.94s/it]

# %% [markdown]
# ## different retial rates

# %%
params={}
params['arrival_rate'] = 1
params['service_rate'] = 1
params['retrial_rate'] = 1
params['given_alpha'] = 0.9
params['num_of_users'] = 20

# %%
params['retrial_rate'] = 0.5
all_nus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_nu(params, all_nus)
plot_all_perf_changing_var(params, all_nus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\nu$", r"$m^*$", "nu")
# Out:
# 30it [04:18,  8.62s/it]

# %%
params['retrial_rate'] = 5
all_nus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_nu(params, all_nus)
plot_all_perf_changing_var(params, all_nus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\nu$", r"$m^*$", "nu")
# Out:
# 30it [04:19,  8.65s/it]

# %%
params['retrial_rate'] = 10
all_nus = np.linspace(0.1, 10, 30)
min_servers, min_servers_lb, min_servers_ub = perf_of_changing_nu(params, all_nus)
plot_all_perf_changing_var(params, all_nus, min_servers, min_servers_lb, min_servers_ub, 1, 2, r"$\nu$", r"$m^*$", "nu")
# Out:
# 30it [04:18,  8.63s/it]
