# %%
from Metrics import *
from loss import *

# %% [markdown]
# # compute the realized $\alpha$ by nominal load

# %%
plot_gap_of_loss(given_alpha=0.2, lambda_=1, mu=1, nu=1, n_lb=2, n_ub=200, n_step=5)
# Out:
# 40it [00:00, 38243.03it/s]

# %%
plot_gap_of_loss(given_alpha=0.5, lambda_=1, mu=1, nu=1, n_lb=2, n_ub=200, n_step=5)
# Out:
# 40it [00:00, 78914.47it/s]

# %%
plot_gap_of_loss(given_alpha=0.9, lambda_=1, mu=1, nu=1, n_lb=2, n_ub=200, n_step=5)
# Out:
# 40it [00:00, 67108.86it/s]

# %% [markdown]
# # Plot bounds of $\overline \alpha(m, n)$

# %% [markdown]
# **Note**:
# we use tighter bound if $\frac{m}{n} < \frac{\lambda}{\lambda + \mu}$, ow, use general bound. So we would see the "jump" around $m = n * \frac{\lambda}{\lambda + \mu}$

# %%
plot_bounds_of_alpha(n=100, lambda_=1, mu=1, nu=1, n_step=2)
# Out:
# 50it [00:00, 139253.12it/s]

# %%
plot_bounds_of_alpha(n=60, lambda_=1, mu=1, nu=2, n_step=3)
# Out:
# 13it [02:28,  9.95s/it]/Users/xiaobingshen/Documents/Research/Staffing Paper Review/Staffing/simulation/loss.py:37: RuntimeWarning: divide by zero encountered in scalar divide
#   return numerator / denominator
# 20it [03:36, 10.84s/it]
